# %% [markdown]
# # Car Counter Project

# %%
import cv2 
import cvzone
import math
from sort import *

# %% [markdown]
# #### Use a pre pretrained Model

# %%
from ultralytics import YOLO
model =YOLO("../Yolo-Weights/yolov8s.pt")

# %% [markdown]
# #### Import all classes

# %%
all_classes = []
with open("../1. Running_YOLO/80Classes.txt","r") as f:
    all_classes = f.read().splitlines()
    # OR : 
    # all_classes = [line.strip() for line in f.readlines()]

# %% [markdown]
# #### Test the mask Operation to select Corresponding Region

# %%
mask = cv2.imread("./Mask.png")
h,w = mask.shape[:2]
bycycle =cv2.imread("../1. Running_YOLO/images/3bikes.jpg")
bycycle = cv2.resize(bycycle,(w,h))

masked_image =cv2.bitwise_and(mask,bycycle)
# cv2.imshow("Mask",masked_image)
# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
# Out:
# -1

# %%
cap = cv2.VideoCapture("../videos/cars.mp4") # Open The Video = '0'
cap.set(cv2.CAP_PROP_FRAME_WIDTH,1280) # Width is equal to 1280 pixels 
cap.set(cv2.CAP_PROP_FRAME_HEIGHT,720)

#create instance of SORT
tracker = Sort(max_age=20 ,min_hits=3,iou_threshold=0.3) 
totalCount = set()

while True:
    success,frame = cap.read()
    img_region = cv2.bitwise_and(frame,mask)
    results =model.predict(img_region, stream=True)

    carLabel =cv2.imread("graphics.png",cv2.IMREAD_UNCHANGED)
    frame =cvzone.overlayPNG(frame,carLabel,(0,0))

    detections = np.empty((0,5))
    cv2.line(frame,(400,297),(673,297),(0,0,255),3)

    for r in results :
          boxes = r.boxes # Len Boxes = Number Of Objects
          centers = []
          for box in boxes:
              #print(box)
              x1,y1,x2,y2 = box.xyxy[0]
              x1,y1,x2,y2 = int(x1),int(y1),int(x2),int(y2)
              w, h = x2-x1, y2-y1
              
              # the Class Name 
              cls = int(box.cls[0])
              class_detected = all_classes[cls]
              #The Confidence Sore 
              conf = math.ceil(box.conf[0]*100)/100 
              
              # Display only the Permitted classes
              if class_detected in ["bicycle","car"] and conf >0.5 :
                
                # Track the Object Detected Only    
                currentArray = np.array([x1,y1,x2,y2,conf])
                detections = np.vstack((detections, currentArray))
                
                # # Display the Bounding Box
                # cvzone.putTextRect(frame,f"{class_detected} {conf} ",(x1,y1+30),colorR=(0,255,0),colorB=(0,0,0),scale=0.8,thickness=1,offset=5)
                cvzone.cornerRect(frame,(x1,y1,w,h),colorR=(255,255,255),rt=1,l=10)
                cx ,cy = x1+w//2,y1+h//2
                #cv2.circle(frame,(cx,cy),5,(0,255,0),cv2.FILLED)
                centers.append([cx,cy])
                
    resultsTrackers = tracker.update(detections)
    
    for i,results in enumerate(resultsTrackers):
         
      x1,y1,x2,y2,id = results
      x1,y1,x2,y2,id = int(x1),int(y1),int(x2),int(y2),int(id)
      #cvzone.cornerRect(frame,(x1,y1,w,h),colorR=(255,0,0),rt=1,l=10)
      #cvzone.putTextRect(frame,str(id),(x1,y1),colorR=(255,0,0),colorB=(255,255,255),scale=1,thickness=2,offset=5) 
      cx ,cy =centers[i]
      cv2.circle(frame,(cx,cy),5,(0,255,0),cv2.FILLED)
      if 297-16 <= cy <= 297+16 and 400<= cx <= 673:
        if id not in totalCount:
          totalCount.add(id)
          cv2.line(frame,(400,297),(673,297),(0,255,0),3)
        
    
    cv2.putText(frame,f"{len(totalCount)}",(200,90),cv2.FONT_HERSHEY_PLAIN,5,(0,255,0),4)
    

    cv2.imshow("frame",frame)

    if cv2.waitKey(100) & 0xFF == ord('q'):
            cv2.destroyAllWindows()
            cap.release()
            break
# Out:
# 0: 384x640 4 cars, 1 truck, 89.1ms
# Speed: 3.2ms preprocess, 89.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 87.8ms
# Speed: 3.6ms preprocess, 87.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 86.9ms
# Speed: 3.0ms preprocess, 86.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 87.5ms
# Speed: 3.2ms preprocess, 87.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 38.9ms
# Speed: 2.1ms preprocess, 38.9ms inference, 5.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 38.8ms
# Speed: 2.2ms preprocess, 38.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 38.8ms
# Speed: 2.8ms preprocess, 38.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 38.8ms
# Speed: 2.6ms preprocess, 38.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 38.8ms
# Speed: 2.4ms preprocess, 38.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 38.8ms
# Speed: 2.2ms preprocess, 38.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 39.0ms
# Speed: 4.6ms preprocess, 39.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 38.8ms
# Speed: 2.3ms preprocess, 38.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 39.0ms
# Speed: 3.6ms preprocess, 39.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 38.9ms
# Speed: 3.2ms preprocess, 38.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 64.6ms
# Speed: 2.2ms preprocess, 64.6ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 motorcycle, 1 truck, 87.2ms
# Speed: 3.7ms preprocess, 87.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 87.1ms
# Speed: 3.1ms preprocess, 87.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 86.8ms
# Speed: 3.1ms preprocess, 86.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 traffic light, 87.3ms
# Speed: 3.1ms preprocess, 87.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 38.8ms
# Speed: 2.3ms preprocess, 38.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 1 motorcycle, 1 truck, 38.8ms
# Speed: 2.1ms preprocess, 38.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 2 motorcycles, 2 trucks, 38.9ms
# Speed: 3.0ms preprocess, 38.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 motorcycle, 1 truck, 38.8ms
# Speed: 2.6ms preprocess, 38.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 motorcycle, 1 truck, 38.8ms
# Speed: 2.3ms preprocess, 38.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 1 motorcycle, 1 truck, 39.3ms
# Speed: 3.3ms preprocess, 39.3ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 38.8ms
# Speed: 2.8ms preprocess, 38.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 39.0ms
# Speed: 3.7ms preprocess, 39.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 38.9ms
# Speed: 3.4ms preprocess, 38.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 39.0ms
# Speed: 3.2ms preprocess, 39.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 38.8ms
# Speed: 2.4ms preprocess, 38.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 86.8ms
# Speed: 3.1ms preprocess, 86.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 39.3ms
# Speed: 2.1ms preprocess, 39.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 39.5ms
# Speed: 3.2ms preprocess, 39.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 39.3ms
# Speed: 2.3ms preprocess, 39.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 39.4ms
# Speed: 2.2ms preprocess, 39.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 39.4ms
# Speed: 2.8ms preprocess, 39.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 39.5ms
# Speed: 3.5ms preprocess, 39.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 39.4ms
# Speed: 2.7ms preprocess, 39.4ms inference, 4.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 39.3ms
# Speed: 2.2ms preprocess, 39.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 39.4ms
# Speed: 2.6ms preprocess, 39.4ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 39.3ms
# Speed: 2.2ms preprocess, 39.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 43.4ms
# Speed: 2.4ms preprocess, 43.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 87.2ms
# Speed: 4.4ms preprocess, 87.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 87.5ms
# Speed: 4.5ms preprocess, 87.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 87.2ms
# Speed: 3.0ms preprocess, 87.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 87.5ms
# Speed: 4.8ms preprocess, 87.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 58.0ms
# Speed: 3.1ms preprocess, 58.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 39.3ms
# Speed: 2.1ms preprocess, 39.3ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 39.5ms
# Speed: 3.4ms preprocess, 39.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 39.4ms
# Speed: 2.5ms preprocess, 39.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 39.6ms
# Speed: 4.9ms preprocess, 39.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 39.3ms
# Speed: 2.1ms preprocess, 39.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 39.4ms
# Speed: 2.2ms preprocess, 39.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 39.3ms
# Speed: 2.2ms preprocess, 39.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 39.5ms
# Speed: 4.8ms preprocess, 39.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 39.4ms
# Speed: 2.7ms preprocess, 39.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 39.3ms
# Speed: 2.5ms preprocess, 39.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 87.7ms
# Speed: 4.8ms preprocess, 87.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 87.1ms
# Speed: 3.0ms preprocess, 87.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 39.6ms
# Speed: 4.1ms preprocess, 39.6ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 39.0ms
# Speed: 2.1ms preprocess, 39.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 39.0ms
# Speed: 2.1ms preprocess, 39.0ms inference, 5.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 39.0ms
# Speed: 3.1ms preprocess, 39.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 39.0ms
# Speed: 2.6ms preprocess, 39.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 39.0ms
# Speed: 2.2ms preprocess, 39.0ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 39.0ms
# Speed: 2.2ms preprocess, 39.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 39.1ms
# Speed: 2.8ms preprocess, 39.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 39.0ms
# Speed: 2.4ms preprocess, 39.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 39.2ms
# Speed: 4.1ms preprocess, 39.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 60.7ms
# Speed: 2.2ms preprocess, 60.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 87.1ms
# Speed: 3.3ms preprocess, 87.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 87.2ms
# Speed: 3.0ms preprocess, 87.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 87.4ms
# Speed: 5.2ms preprocess, 87.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 87.3ms
# Speed: 3.7ms preprocess, 87.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 38.7ms
# Speed: 2.4ms preprocess, 38.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 38.9ms
# Speed: 2.9ms preprocess, 38.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 38.8ms
# Speed: 2.1ms preprocess, 38.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 38.9ms
# Speed: 2.9ms preprocess, 38.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 38.8ms
# Speed: 2.2ms preprocess, 38.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 39.0ms
# Speed: 3.1ms preprocess, 39.0ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 38.8ms
# Speed: 2.7ms preprocess, 38.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 38.8ms
# Speed: 2.2ms preprocess, 38.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 38.9ms
# Speed: 3.5ms preprocess, 38.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 38.8ms
# Speed: 2.6ms preprocess, 38.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 38.8ms
# Speed: 2.3ms preprocess, 38.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 86.7ms
# Speed: 2.9ms preprocess, 86.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 39.5ms
# Speed: 4.0ms preprocess, 39.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 39.4ms
# Speed: 2.4ms preprocess, 39.4ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 39.5ms
# Speed: 3.1ms preprocess, 39.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 39.6ms
# Speed: 4.6ms preprocess, 39.6ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 39.4ms
# Speed: 2.9ms preprocess, 39.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 39.6ms
# Speed: 4.5ms preprocess, 39.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 39.5ms
# Speed: 3.6ms preprocess, 39.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 39.5ms
# Speed: 3.5ms preprocess, 39.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 39.3ms
# Speed: 2.1ms preprocess, 39.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 39.3ms
# Speed: 2.1ms preprocess, 39.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 39.4ms
# Speed: 2.9ms preprocess, 39.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 87.3ms
# Speed: 3.5ms preprocess, 87.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 39.1ms
# Speed: 3.6ms preprocess, 39.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 39.3ms
# Speed: 3.4ms preprocess, 39.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 39.0ms
# Speed: 3.2ms preprocess, 39.0ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 38.9ms
# Speed: 2.1ms preprocess, 38.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 39.0ms
# Speed: 2.3ms preprocess, 39.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 2 trucks, 39.1ms
# Speed: 3.2ms preprocess, 39.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 39.1ms
# Speed: 3.6ms preprocess, 39.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 39.0ms
# Speed: 2.2ms preprocess, 39.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 39.0ms
# Speed: 2.3ms preprocess, 39.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 39.1ms
# Speed: 2.9ms preprocess, 39.1ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 47.9ms
# Speed: 2.2ms preprocess, 47.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 78.8ms
# Speed: 3.3ms preprocess, 78.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 39.4ms
# Speed: 2.2ms preprocess, 39.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 39.5ms
# Speed: 4.0ms preprocess, 39.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 39.4ms
# Speed: 2.4ms preprocess, 39.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 39.3ms
# Speed: 2.7ms preprocess, 39.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 39.4ms
# Speed: 3.8ms preprocess, 39.4ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 39.5ms
# Speed: 5.8ms preprocess, 39.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 39.4ms
# Speed: 3.2ms preprocess, 39.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 39.4ms
# Speed: 3.9ms preprocess, 39.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 39.3ms
# Speed: 2.2ms preprocess, 39.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 39.4ms
# Speed: 2.6ms preprocess, 39.4ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 87.7ms
# Speed: 3.6ms preprocess, 87.7ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 9 cars, 1 truck, 86.9ms
# Speed: 3.6ms preprocess, 86.9ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 2 trucks, 87.2ms
# Speed: 3.2ms preprocess, 87.2ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 2 trucks, 38.9ms
# Speed: 2.9ms preprocess, 38.9ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 38.9ms
# Speed: 2.5ms preprocess, 38.9ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 38.8ms
# Speed: 2.9ms preprocess, 38.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 38.8ms
# Speed: 2.3ms preprocess, 38.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 38.7ms
# Speed: 2.1ms preprocess, 38.7ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 38.9ms
# Speed: 3.6ms preprocess, 38.9ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 38.9ms
# Speed: 2.7ms preprocess, 38.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 38.8ms
# Speed: 2.3ms preprocess, 38.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 38.8ms
# Speed: 2.6ms preprocess, 38.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 38.8ms
# Speed: 2.2ms preprocess, 38.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 38.8ms
# Speed: 2.1ms preprocess, 38.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 87.3ms
# Speed: 4.3ms preprocess, 87.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 87.2ms
# Speed: 2.9ms preprocess, 87.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 87.5ms
# Speed: 4.0ms preprocess, 87.5ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 87.3ms
# Speed: 4.0ms preprocess, 87.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 87.7ms
# Speed: 4.1ms preprocess, 87.7ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 87.7ms
# Speed: 3.1ms preprocess, 87.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 38.9ms
# Speed: 2.6ms preprocess, 38.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 38.8ms
# Speed: 2.2ms preprocess, 38.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 38.8ms
# Speed: 2.2ms preprocess, 38.8ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 39.0ms
# Speed: 4.2ms preprocess, 39.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 38.9ms
# Speed: 3.7ms preprocess, 38.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 38.8ms
# Speed: 2.3ms preprocess, 38.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 38.9ms
# Speed: 2.2ms preprocess, 38.9ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 38.8ms
# Speed: 2.1ms preprocess, 38.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 39.1ms
# Speed: 3.1ms preprocess, 39.1ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 38.8ms
# Speed: 2.6ms preprocess, 38.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 38.8ms
# Speed: 2.5ms preprocess, 38.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 87.2ms
# Speed: 4.9ms preprocess, 87.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 87.2ms
# Speed: 3.1ms preprocess, 87.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 3 trucks, 39.0ms
# Speed: 3.0ms preprocess, 39.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 3 trucks, 38.9ms
# Speed: 3.7ms preprocess, 38.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 38.9ms
# Speed: 2.9ms preprocess, 38.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 2 trucks, 39.6ms
# Speed: 4.8ms preprocess, 39.6ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 1 bus, 2 trucks, 38.9ms
# Speed: 3.1ms preprocess, 38.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 2 trucks, 38.8ms
# Speed: 2.7ms preprocess, 38.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 39.0ms
# Speed: 4.3ms preprocess, 39.0ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 38.8ms
# Speed: 2.8ms preprocess, 38.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 38.7ms
# Speed: 2.4ms preprocess, 38.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 39.1ms
# Speed: 4.7ms preprocess, 39.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 38.8ms
# Speed: 3.0ms preprocess, 38.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 39.1ms
# Speed: 3.2ms preprocess, 39.1ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 39.3ms
# Speed: 2.2ms preprocess, 39.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 87.6ms
# Speed: 4.0ms preprocess, 87.6ms inference, 5.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 38.9ms
# Speed: 2.9ms preprocess, 38.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 39.1ms
# Speed: 5.2ms preprocess, 39.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 38.8ms
# Speed: 2.2ms preprocess, 38.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 truck, 38.8ms
# Speed: 2.2ms preprocess, 38.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 2 buss, 1 truck, 38.9ms
# Speed: 2.3ms preprocess, 38.9ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 38.9ms
# Speed: 3.1ms preprocess, 38.9ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 1 train, 38.8ms
# Speed: 2.9ms preprocess, 38.8ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 38.8ms
# Speed: 2.2ms preprocess, 38.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 bus, 38.9ms
# Speed: 2.7ms preprocess, 38.9ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 38.9ms
# Speed: 3.0ms preprocess, 38.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 truck, 38.8ms
# Speed: 2.6ms preprocess, 38.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 87.2ms
# Speed: 6.4ms preprocess, 87.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 airplane, 87.3ms
# Speed: 3.5ms preprocess, 87.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 38.8ms
# Speed: 2.1ms preprocess, 38.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 38.7ms
# Speed: 2.2ms preprocess, 38.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 38.9ms
# Speed: 2.5ms preprocess, 38.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 38.8ms
# Speed: 2.4ms preprocess, 38.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 38.8ms
# Speed: 2.2ms preprocess, 38.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 38.8ms
# Speed: 2.6ms preprocess, 38.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 38.8ms
# Speed: 2.8ms preprocess, 38.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 38.8ms
# Speed: 2.3ms preprocess, 38.8ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 38.7ms
# Speed: 2.1ms preprocess, 38.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 38.7ms
# Speed: 2.1ms preprocess, 38.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 38.9ms
# Speed: 3.1ms preprocess, 38.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 39.3ms
# Speed: 2.3ms preprocess, 39.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 87.7ms
# Speed: 4.7ms preprocess, 87.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 38.8ms
# Speed: 2.1ms preprocess, 38.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 38.8ms
# Speed: 2.8ms preprocess, 38.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 38.8ms
# Speed: 2.2ms preprocess, 38.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 38.8ms
# Speed: 3.0ms preprocess, 38.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 38.8ms
# Speed: 2.4ms preprocess, 38.8ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 38.9ms
# Speed: 3.6ms preprocess, 38.9ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 truck, 38.8ms
# Speed: 2.5ms preprocess, 38.8ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 mouse, 38.8ms
# Speed: 2.0ms preprocess, 38.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 38.8ms
# Speed: 2.7ms preprocess, 38.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 39.0ms
# Speed: 5.0ms preprocess, 39.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 38.8ms
# Speed: 2.6ms preprocess, 38.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 87.4ms
# Speed: 3.6ms preprocess, 87.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 87.5ms
# Speed: 3.9ms preprocess, 87.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 87.4ms
# Speed: 4.8ms preprocess, 87.4ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 87.6ms
# Speed: 3.6ms preprocess, 87.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 87.5ms
# Speed: 3.0ms preprocess, 87.5ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 87.4ms
# Speed: 3.1ms preprocess, 87.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 38.8ms
# Speed: 2.9ms preprocess, 38.8ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 38.8ms
# Speed: 2.1ms preprocess, 38.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 38.9ms
# Speed: 2.3ms preprocess, 38.9ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 38.7ms
# Speed: 2.0ms preprocess, 38.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 1 truck, 38.7ms
# Speed: 2.2ms preprocess, 38.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 38.8ms
# Speed: 2.2ms preprocess, 38.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 38.8ms
# Speed: 2.0ms preprocess, 38.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 38.8ms
# Speed: 2.1ms preprocess, 38.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 38.8ms
# Speed: 2.2ms preprocess, 38.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 38.8ms
# Speed: 2.1ms preprocess, 38.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 38.9ms
# Speed: 3.1ms preprocess, 38.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 86.9ms
# Speed: 3.1ms preprocess, 86.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 39.4ms
# Speed: 2.1ms preprocess, 39.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 39.3ms
# Speed: 2.1ms preprocess, 39.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 39.3ms
# Speed: 2.2ms preprocess, 39.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 39.4ms
# Speed: 2.8ms preprocess, 39.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 39.4ms
# Speed: 2.2ms preprocess, 39.4ms inference, 2.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 39.4ms
# Speed: 2.8ms preprocess, 39.4ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 39.3ms
# Speed: 2.0ms preprocess, 39.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 39.3ms
# Speed: 2.3ms preprocess, 39.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 39.4ms
# Speed: 2.2ms preprocess, 39.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 39.4ms
# Speed: 3.1ms preprocess, 39.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 39.3ms
# Speed: 2.2ms preprocess, 39.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 87.3ms
# Speed: 3.1ms preprocess, 87.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 1 airplane, 87.1ms
# Speed: 3.0ms preprocess, 87.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 39.0ms
# Speed: 3.1ms preprocess, 39.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 39.0ms
# Speed: 2.3ms preprocess, 39.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 39.0ms
# Speed: 2.3ms preprocess, 39.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 39.0ms
# Speed: 2.5ms preprocess, 39.0ms inference, 3.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 39.0ms
# Speed: 2.4ms preprocess, 39.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 39.3ms
# Speed: 5.2ms preprocess, 39.3ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 39.0ms
# Speed: 2.6ms preprocess, 39.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 39.3ms
# Speed: 4.6ms preprocess, 39.3ms inference, 4.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 39.0ms
# Speed: 2.4ms preprocess, 39.0ms inference, 3.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 39.4ms
# Speed: 4.9ms preprocess, 39.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 39.0ms
# Speed: 2.7ms preprocess, 39.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 39.3ms
# Speed: 2.2ms preprocess, 39.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 87.4ms
# Speed: 3.0ms preprocess, 87.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 38.9ms
# Speed: 2.9ms preprocess, 38.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 38.9ms
# Speed: 2.9ms preprocess, 38.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 38.8ms
# Speed: 2.3ms preprocess, 38.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 38.9ms
# Speed: 2.9ms preprocess, 38.9ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 39.3ms
# Speed: 4.5ms preprocess, 39.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 38.9ms
# Speed: 3.7ms preprocess, 38.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 38.9ms
# Speed: 2.8ms preprocess, 38.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 38.8ms
# Speed: 2.7ms preprocess, 38.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 38.9ms
# Speed: 2.2ms preprocess, 38.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 39.0ms
# Speed: 3.4ms preprocess, 39.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 68.1ms
# Speed: 2.2ms preprocess, 68.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 87.8ms
# Speed: 3.0ms preprocess, 87.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 87.4ms
# Speed: 3.0ms preprocess, 87.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 87.3ms
# Speed: 3.0ms preprocess, 87.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 39.1ms
# Speed: 2.2ms preprocess, 39.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 39.1ms
# Speed: 2.2ms preprocess, 39.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 39.2ms
# Speed: 2.9ms preprocess, 39.2ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 39.2ms
# Speed: 2.8ms preprocess, 39.2ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 39.1ms
# Speed: 2.4ms preprocess, 39.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 39.1ms
# Speed: 2.4ms preprocess, 39.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 39.1ms
# Speed: 2.1ms preprocess, 39.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 39.1ms
# Speed: 2.1ms preprocess, 39.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 39.2ms
# Speed: 2.9ms preprocess, 39.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 39.3ms
# Speed: 4.0ms preprocess, 39.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 39.1ms
# Speed: 2.2ms preprocess, 39.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 87.1ms
# Speed: 3.0ms preprocess, 87.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 39.1ms
# Speed: 2.1ms preprocess, 39.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 39.2ms
# Speed: 2.7ms preprocess, 39.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 8 cars, 1 truck, 39.2ms
# Speed: 2.9ms preprocess, 39.2ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 7 cars, 1 truck, 39.1ms
# Speed: 2.1ms preprocess, 39.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 39.1ms
# Speed: 2.3ms preprocess, 39.1ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 39.2ms
# Speed: 3.9ms preprocess, 39.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 39.3ms
# Speed: 4.5ms preprocess, 39.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 39.2ms
# Speed: 2.2ms preprocess, 39.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 39.1ms
# Speed: 2.5ms preprocess, 39.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 39.4ms
# Speed: 5.8ms preprocess, 39.4ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 65.0ms
# Speed: 2.9ms preprocess, 65.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 87.9ms
# Speed: 4.9ms preprocess, 87.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 87.8ms
# Speed: 6.0ms preprocess, 87.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 87.3ms
# Speed: 3.0ms preprocess, 87.3ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 trucks, 39.9ms
# Speed: 5.9ms preprocess, 39.9ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 39.2ms
# Speed: 2.3ms preprocess, 39.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 39.2ms
# Speed: 2.9ms preprocess, 39.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 39.1ms
# Speed: 2.1ms preprocess, 39.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 39.1ms
# Speed: 2.2ms preprocess, 39.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 39.2ms
# Speed: 2.2ms preprocess, 39.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 39.1ms
# Speed: 2.2ms preprocess, 39.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 39.1ms
# Speed: 2.3ms preprocess, 39.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 39.2ms
# Speed: 2.4ms preprocess, 39.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 39.1ms
# Speed: 2.7ms preprocess, 39.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 39.1ms
# Speed: 2.2ms preprocess, 39.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 86.8ms
# Speed: 2.9ms preprocess, 86.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 39.3ms
# Speed: 2.1ms preprocess, 39.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 39.3ms
# Speed: 2.6ms preprocess, 39.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 39.3ms
# Speed: 2.2ms preprocess, 39.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 39.4ms
# Speed: 2.2ms preprocess, 39.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 39.8ms
# Speed: 5.0ms preprocess, 39.8ms inference, 4.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 39.5ms
# Speed: 4.1ms preprocess, 39.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 39.4ms
# Speed: 2.3ms preprocess, 39.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 cars, 39.3ms
# Speed: 2.3ms preprocess, 39.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 39.3ms
# Speed: 2.1ms preprocess, 39.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 39.5ms
# Speed: 5.0ms preprocess, 39.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 39.5ms
# Speed: 3.0ms preprocess, 39.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 87.4ms
# Speed: 6.1ms preprocess, 87.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 87.2ms
# Speed: 3.7ms preprocess, 87.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 87.2ms
# Speed: 3.6ms preprocess, 87.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 87.4ms
# Speed: 3.6ms preprocess, 87.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 87.3ms
# Speed: 3.0ms preprocess, 87.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 87.2ms
# Speed: 3.1ms preprocess, 87.2ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 39.0ms
# Speed: 2.4ms preprocess, 39.0ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 39.1ms
# Speed: 2.8ms preprocess, 39.1ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 39.0ms
# Speed: 2.1ms preprocess, 39.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 39.0ms
# Speed: 2.1ms preprocess, 39.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 39.0ms
# Speed: 2.2ms preprocess, 39.0ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 39.0ms
# Speed: 2.5ms preprocess, 39.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 39.0ms
# Speed: 2.3ms preprocess, 39.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 39.1ms
# Speed: 3.7ms preprocess, 39.1ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 39.0ms
# Speed: 2.1ms preprocess, 39.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 38.9ms
# Speed: 2.6ms preprocess, 38.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 39.0ms
# Speed: 2.1ms preprocess, 39.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 87.1ms
# Speed: 6.1ms preprocess, 87.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 2 buss, 39.5ms
# Speed: 3.8ms preprocess, 39.5ms inference, 2.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 39.3ms
# Speed: 2.1ms preprocess, 39.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 39.3ms
# Speed: 2.4ms preprocess, 39.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 39.3ms
# Speed: 2.5ms preprocess, 39.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 39.4ms
# Speed: 2.0ms preprocess, 39.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 39.3ms
# Speed: 2.2ms preprocess, 39.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 bus, 39.5ms
# Speed: 2.5ms preprocess, 39.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 39.4ms
# Speed: 2.6ms preprocess, 39.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 bus, 39.4ms
# Speed: 2.2ms preprocess, 39.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 39.5ms
# Speed: 4.8ms preprocess, 39.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 39.4ms
# Speed: 2.4ms preprocess, 39.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 86.8ms
# Speed: 3.3ms preprocess, 86.8ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 87.2ms
# Speed: 3.6ms preprocess, 87.2ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 38.8ms
# Speed: 2.3ms preprocess, 38.8ms inference, 5.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 38.9ms
# Speed: 2.4ms preprocess, 38.9ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 39.0ms
# Speed: 3.3ms preprocess, 39.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 38.8ms
# Speed: 2.4ms preprocess, 38.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 38.9ms
# Speed: 2.5ms preprocess, 38.9ms inference, 3.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 2 trucks, 38.9ms
# Speed: 3.1ms preprocess, 38.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 bus, 1 truck, 38.8ms
# Speed: 2.2ms preprocess, 38.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 38.9ms
# Speed: 2.3ms preprocess, 38.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 38.9ms
# Speed: 3.9ms preprocess, 38.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 38.8ms
# Speed: 2.1ms preprocess, 38.8ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 52.8ms
# Speed: 3.6ms preprocess, 52.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 87.3ms
# Speed: 3.1ms preprocess, 87.3ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 87.3ms
# Speed: 4.2ms preprocess, 87.3ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 87.4ms
# Speed: 3.1ms preprocess, 87.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 5 cars, 2 trucks, 87.5ms
# Speed: 3.8ms preprocess, 87.5ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 4 cars, 2 trucks, 39.0ms
# Speed: 4.2ms preprocess, 39.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 6 cars, 1 truck, 38.8ms
# Speed: 2.7ms preprocess, 38.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 3 cars, 1 truck, 38.9ms
# Speed: 3.1ms preprocess, 38.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 38.8ms
# Speed: 2.4ms preprocess, 38.8ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 38.8ms
# Speed: 2.4ms preprocess, 38.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 cars, 1 truck, 39.0ms
# Speed: 4.1ms preprocess, 39.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 6 cars, 1 truck, 38.9ms
# Speed: 2.9ms preprocess, 38.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 1 truck, 38.8ms
# Speed: 2.7ms preprocess, 38.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 1 truck, 38.9ms
# Speed: 3.1ms preprocess, 38.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 38.8ms
# Speed: 3.1ms preprocess, 38.8ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 cars, 38.8ms
# Speed: 2.7ms preprocess, 38.8ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[94], line 11
#       9 while True:
#      10     success,frame = cap.read()
# ---> 11     img_region = cv2.bitwise_and(frame,mask)
#      12     results =model.predict(img_region, stream=True)
#      14     carLabel =cv2.imread("graphics.png",cv2.IMREAD_UNCHANGED)
#
# error: OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\core\src\arithm.cpp:214: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and type), nor 'array op scalar', nor 'scalar op array' in function 'cv::binary_op'
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
